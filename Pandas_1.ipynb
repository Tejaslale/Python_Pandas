# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('cost_living.csv')

# %%
df.head()
# Out:
#    Rank      Country  Cost of Living Index  Rent Index  \
# 0     1  Switzerland                 101.1        46.5
# 1     2      Bahamas                  85.0        36.7
# 2     3      Iceland                  83.0        39.2
# 3     4    Singapore                  76.7        67.2
# 4     5     Barbados                  76.6        19.0
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            74.9            109.1                    97.0
# 1                            61.8             81.6                    83.3
# 2                            62.0             88.4                    86.8
# 3                            72.1             74.6                    50.4
# 4                            48.9             80.8                    69.4
#
#    Local Purchasing Power Index
# 0                         158.7
# 1                          54.6
# 2                         120.3
# 3                         111.1
# ...

# %%
df.head(2)
# Out:
#    Rank      Country  Cost of Living Index  Rent Index  \
# 0     1  Switzerland                 101.1        46.5
# 1     2      Bahamas                  85.0        36.7
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            74.9            109.1                    97.0
# 1                            61.8             81.6                    83.3
#
#    Local Purchasing Power Index
# 0                         158.7
# 1                          54.6

# %%
df.tail(3)
# Out:
#      Rank   Country  Cost of Living Index  Rent Index  \
# 118   119     Egypt                  21.0         3.7
# 119   120     Libya                  20.4         4.3
# 120   121  Pakistan                  18.8         2.8
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 118                            12.7             21.2                    16.2
# 119                            12.7             22.2                    15.2
# 120                            11.1             17.5                    12.9
#
#      Local Purchasing Power Index
# 118                          20.0
# 119                          42.0
# 120                          29.1

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
list(df.columns)
# Out:
# ['Rank',
#  'Country',
#  'Cost of Living Index',
#  'Rent Index',
#  'Cost of Living Plus Rent Index',
#  'Groceries Index',
#  'Restaurant Price Index',
#  'Local Purchasing Power Index']

# %%
type(df['Rank'])
# Out:
# pandas.core.series.Series

# %%
list(df['Country'])
# Out:
# ['Switzerland',
#  'Bahamas',
#  'Iceland',
#  'Singapore',
#  'Barbados',
#  'Norway',
#  'Denmark',
#  'Hong Kong (China)',
#  'United States',
#  'Australia',
#  'Austria',
#  'Canada',
#  'New Zealand',
#  'Ireland',
#  'France',
#  'Puerto Rico',
#  'Finland',
#  'Netherlands',
#  'Israel',
#  'Luxembourg',
#  'Germany',
#  'United Kingdom',
#  'Belgium',
#  'South Korea',
#  'Sweden',
#  'Italy',
#  'United Arab Emirates',
#  'Cyprus',
#  'Uruguay',
#  'Jamaica',
#  'Malta',
#  'Trinidad And Tobago',
#  'Costa Rica',
#  'Bahrain',
#  'Greece',
#  'Estonia',
#  'Qatar',
#  'Slovenia',
#  'Latvia',
#  'Spain',
#  'Lithuania',
#  'Slovakia',
#  'Cuba',
#  'Czech Republic',
#  'Panama',
#  'Japan',
#  'Croatia',
#  'Saudi Arabia',
#  'Taiwan',
#  'Portugal',
#  'Oman',
#  'Kuwait',
#  'Albania',
#  'Lebanon',
#  'Hungary',
#  'Palestine',
#  'Jordan',
#  'Armenia',
#  'Poland',
#  'Mexico',
#  'El Salvador',
#  'Montenegro',
#  'Chile',
#  'Guatemala',
#  'Venezuela',
# ...

# %%
df[['Country']]
# Out:
#          Country
# 0    Switzerland
# 1        Bahamas
# 2        Iceland
# 3      Singapore
# 4       Barbados
# ..           ...
# 116   Bangladesh
# 117        India
# 118        Egypt
# 119        Libya
# 120     Pakistan
#
# [121 rows x 1 columns]

# %%
type(df[['Country']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Rank','Country','Rent Index','Cost of Living Index']]
# Out:
#      Rank      Country  Rent Index  Cost of Living Index
# 0       1  Switzerland        46.5                 101.1
# 1       2      Bahamas        36.7                  85.0
# 2       3      Iceland        39.2                  83.0
# 3       4    Singapore        67.2                  76.7
# 4       5     Barbados        19.0                  76.6
# ..    ...          ...         ...                   ...
# 116   117   Bangladesh         2.4                  22.5
# 117   118        India         5.6                  21.2
# 118   119        Egypt         3.7                  21.0
# 119   120        Libya         4.3                  20.4
# 120   121     Pakistan         2.8                  18.8
#
# [121 rows x 4 columns]

# %%
df1 = pd.read_excel('Apricots.xlsx')

# %%
df1
# Out:
#    Apricots—Average retail price per pound and per cup equivalent, 2022  \
# 0                                                Form
# 1                                              Fresh1
# 2                                              Canned
# 3                                    Packed in juice2
# 4                           Packed in syrup or water3
# 5                                              Dried4
# 6   1USDA, Agricultural Research Service’s (ARS) N...
# 7   2Consumers are assumed to eat the solid fruit ...
# 8   3The syrup (or water) is discarded prior to co...
# 9   4Includes dried apricots and dried apricot pie...
# 10  Source: USDA, Economic Research Service (ERS) ...
#
#                Unnamed: 1  Unnamed: 2                Unnamed: 3  \
# 0   Average retail price          NaN  Preparation yield factor
# 1                  3.6162   per pound                      0.93
# 2                     NaN         NaN                       NaN
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes.count
# Out:
# <bound method Series.count of Apricots—Average retail price per pound and per cup equivalent, 2022    object
# Unnamed: 1                                                              object
# Unnamed: 2                                                              object
# Unnamed: 3                                                              object
# Unnamed: 4                                                              object
# Unnamed: 5                                                              object
# Unnamed: 6                                                              object
# dtype: object>

# %%
df1.columns
# Out:
# Index(['Apricots—Average retail price per pound and per cup equivalent, 2022',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %%
df1[['Unnamed: 1','Unnamed: 2','Unnamed: 3','Unnamed: 4']]
# Out:
#                Unnamed: 1  Unnamed: 2                Unnamed: 3  \
# 0   Average retail price          NaN  Preparation yield factor
# 1                  3.6162   per pound                      0.93
# 2                     NaN         NaN                       NaN
# 3                  1.8645   per pound                         1
# 4                2.236165   per pound                      0.65
# 5                7.661116   per pound                         1
# 6                     NaN         NaN                       NaN
# 7                     NaN         NaN                       NaN
# 8                     NaN         NaN                       NaN
# 9                     NaN         NaN                       NaN
# 10                    NaN         NaN                       NaN
#
#                    Unnamed: 4
# 0   Size of a cup equivalent
# 1                    0.363763
# 2                         NaN
# 3                    0.540133
# 4                    0.440925
# ...

# %%
df1.ndim
# Out:
# 2

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df2['Survived'])
# Out:
# pandas.core.series.Series

# %%
df2[['Survived','Pclass','Name']]
# Out:
#      Survived  Pclass                                               Name
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
# [891 rows x 3 columns]

# %%
df2.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
import lxml
import pandas as pd
url_data = pd.read_html("https://www.icicidirect.com/equity/index/nse/nifty-50/20559")

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
type(url_data)
# Out:
# list

# %%
df4 = url_data[0]

# %%
df4
# Out:
#                                Company Name      PE  Mcap/Sales  P/BV  \
# 0                          Asian Paints Ltd   58.54        8.38  0.06
# 1                  Britannia Industries Ltd   63.86        8.41  0.03
# 2                                 Cipla Ltd   27.83        4.80  0.22
# 3                         Eicher Motors Ltd   31.87        7.93  0.14
# 4                          Nestle India Ltd   74.67        9.60  0.01
# 5                     Grasim Industries Ltd   29.26        1.32  0.51
# 6                         Hero MotoCorp Ltd   27.37        2.73  0.17
# 7                   Hindalco Industries Ltd   13.44        0.63  0.77
# 8                    Hindustan Unilever Ltd   62.52       10.44  0.08
# 9                                   ITC Ltd   29.66        8.56  0.12
# 10                      Larsen & Toubro Ltd   37.05        2.23  0.18
# 11                  Mahindra & Mahindra Ltd   29.63        2.35  0.20
# ...

# %%
df4.columns
# Out:
# Index(['Company Name', 'PE', 'Mcap/Sales', 'P/BV', 'EV/EBIDTA', 'D/E', 'ROCE',
#        'ROE'],
#       dtype='object')

# %%
df4.to_csv("nifty50.csv",index=False)

# %%
df4
# Out:
#                                Company Name      PE  Mcap/Sales  P/BV  \
# 0                          Asian Paints Ltd   58.54        8.38  0.06
# 1                  Britannia Industries Ltd   63.86        8.41  0.03
# 2                                 Cipla Ltd   27.83        4.80  0.22
# 3                         Eicher Motors Ltd   31.87        7.93  0.14
# 4                          Nestle India Ltd   74.67        9.60  0.01
# 5                     Grasim Industries Ltd   29.26        1.32  0.51
# 6                         Hero MotoCorp Ltd   27.37        2.73  0.17
# 7                   Hindalco Industries Ltd   13.44        0.63  0.77
# 8                    Hindustan Unilever Ltd   62.52       10.44  0.08
# 9                                   ITC Ltd   29.66        8.56  0.12
# 10                      Larsen & Toubro Ltd   37.05        2.23  0.18
# 11                  Mahindra & Mahindra Ltd   29.63        2.35  0.20
# ...
