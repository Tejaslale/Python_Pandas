# %%
import pandas as pd

# %%
dataa =  pd.DataFrame({
    'name': ['John', 'Jane', 'Bob', 'Alice', 'Mike', 'Emily', 'David', 'Sarah', 'Tom', 'Linda'],
    'age': [21, 22, , 24, 25, 26, 27, 28, 29, 29],
    'address': ['Street', '', 'Boulevard', ' Road', 'Lane', ' Parkway', ' Circle', ' Drive', 'Trail', 'Way'],
    'gender': ['Male', 'Female', 'Female', 'Male', '', 'Male', 'Female', 'Male', 'Female', 'Male'],
    'marks': [85, 90, 78, 92, 88, 76, 95, 89, 80, 87]
})
dataa
# Out:
#   File "<ipython-input-100-69c48b89d973>", line 3
#     'age': [21, 22, , 24, 25, 26, 27, 28, 29, 29],
#                     ^
# SyntaxError: invalid syntax

# %%
dataa.to_csv('my_data.csv',index=False)

# %%
my_data = pd.read_csv('my_data.csv')

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     10 non-null     object
#  1   age      10 non-null     int64
#  2   address  9 non-null      object
#  3   gender   9 non-null      object
#  4   marks    10 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
my_data.head(2)
# Out:
#    name  age address  gender  marks
# 0  John   21  Street    Male     85
# 1  Jane   22     NaN  Female     90

# %%
my_data.tail()
# Out:
#     name  age   address  gender  marks
# 5  Emily   26   Parkway    Male     76
# 6  David   27    Circle  Female     95
# 7  Sarah   28     Drive    Male     89
# 8    Tom   29     Trail  Female     80
# 9  Linda   29       Way    Male     87

# %%
my_data.tail(7)
# Out:
#     name  age   address  gender  marks
# 3  Alice   24      Road    Male     92
# 4   Mike   25      Lane     NaN     88
# 5  Emily   26   Parkway    Male     76
# 6  David   27    Circle  Female     95
# 7  Sarah   28     Drive    Male     89
# 8    Tom   29     Trail  Female     80
# 9  Linda   29       Way    Male     87

# %%
ages = pd.Series([27,28,23,24,34],name = 'Age')
ages
# Out:
# 0    27
# 1    28
# 2    23
# 3    24
# 4    34
# Name: Age, dtype: int64

# %%
my_data.isnull().sum()
# Out:
# name       0
# age        0
# address    1
# gender     1
# marks      0
# dtype: int64

# %%
df_new = my_data.dropna()
df_new
# Out:
#     name  age    address  gender  marks
# 0   John   21     Street    Male     85
# 2    Bob   23  Boulevard  Female     78
# 3  Alice   24       Road    Male     92
# 5  Emily   26    Parkway    Male     76
# 6  David   27     Circle  Female     95
# 7  Sarah   28      Drive    Male     89
# 8    Tom   29      Trail  Female     80
# 9  Linda   29        Way    Male     87

# %%
my_data['age'].min()
# Out:
# 21

# %%
my_data['age'].max()
# Out:
# 29

# %%
my_data['age'].std()
# Out:
# 2.8751811537130436

# %%
my_data['age'].count()
# Out:
# 10

# %%
my_data['age'].mean()
# Out:
# 25.4

# %%
my_data['age'].mode()
# Out:
# 0    29
# Name: age, dtype: int64

# %%
my_data['age'].median()
# Out:
# 25.5

# %%
my_data.describe()
# Out:
#              age      marks
# count  10.000000  10.000000
# mean   25.400000  86.000000
# std     2.875181   6.218253
# min    21.000000  76.000000
# 25%    23.250000  81.250000
# 50%    25.500000  87.500000
# 75%    27.750000  89.750000
# max    29.000000  95.000000

# %%
my_data['gender'].describe()
# Out:
# count        9
# unique       2
# top       Male
# freq         5
# Name: gender, dtype: object

# %%
my_data['address'].fillna('Pune',inplace=True)
my_data
# Out:
#     name  age    address  gender  marks
# 0   John   21     Street    Male     85
# 1   Jane   22       Pune  Female     90
# 2    Bob   23  Boulevard  Female     78
# 3  Alice   24       Road    Male     92
# 4   Mike   25       Lane     NaN     88
# 5  Emily   26    Parkway    Male     76
# 6  David   27     Circle  Female     95
# 7  Sarah   28      Drive    Male     89
# 8    Tom   29      Trail  Female     80
# 9  Linda   29        Way    Male     87

# %%
my_data['gender'].fillna('Male',inplace=True)
my_data
# Out:
#     name  age    address  gender  marks
# 0   John   21     Street    Male     85
# 1   Jane   22       Pune  Female     90
# 2    Bob   23  Boulevard  Female     78
# 3  Alice   24       Road    Male     92
# 4   Mike   25       Lane    Male     88
# 5  Emily   26    Parkway    Male     76
# 6  David   27     Circle  Female     95
# 7  Sarah   28      Drive    Male     89
# 8    Tom   29      Trail  Female     80
# 9  Linda   29        Way    Male     87

# %%
my_data['address'].replace('Pune', 'NewAddress', inplace=True)
my_data
# Out:
#     name  age     address  gender  marks
# 0   John   21      Street    Male     85
# 1   Jane   22  NewAddress  Female     90
# 2    Bob   23   Boulevard  Female     78
# 3  Alice   24        Road    Male     92
# 4   Mike   25        Lane    Male     88
# 5  Emily   26     Parkway    Male     76
# 6  David   27      Circle  Female     95
# 7  Sarah   28       Drive    Male     89
# 8    Tom   29       Trail  Female     80
# 9  Linda   29         Way    Male     87

# %%
x = my_data['age'].fillna(method='bfill')
x
# Out:
# <ipython-input-122-4e568c513b0d>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   x = my_data['age'].fillna(method='bfill')
# 0    21
# 1    22
# 2    23
# 3    24
# 4    25
# 5    26
# 6    27
# 7    28
# 8    29
# 9    29
# Name: age, dtype: int64

# %%
my_data['age'].fillna(my_data['age'].mean(),inplace=True)
my_data
# Out:
#     name  age     address  gender  marks
# 0   John   21      Street    Male     85
# 1   Jane   22  NewAddress  Female     90
# 2    Bob   23   Boulevard  Female     78
# 3  Alice   24        Road    Male     92
# 4   Mike   25        Lane    Male     88
# 5  Emily   26     Parkway    Male     76
# 6  David   27      Circle  Female     95
# 7  Sarah   28       Drive    Male     89
# 8    Tom   29       Trail  Female     80
# 9  Linda   29         Way    Male     87

# %%
my_data.plot(x='name',y='marks',kind='bar',title='Line Plot',legend=True)
# Out:
# <Axes: title={'center': 'Line Plot'}, xlabel='name'>

# %%
my_data.plot(x='name',y='marks',kind='barh',title='Line Plot',legend=True)
# Out:
# <Axes: title={'center': 'Line Plot'}, ylabel='name'>

# %%
my_data.plot(x='name',y='marks',kind='pie',title='Line Plot',legend=True)
# Out:
# <Axes: title={'center': 'Line Plot'}, ylabel='marks'>
